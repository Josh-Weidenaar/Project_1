# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
from scipy import stats
import pandas as pd
import json
from pprint import pprint

# %%
# api_key = "TZRAh8OX5nwgY2J2Y2OWeKLqGI__SjwuVzr8V0wj4kHGSEAMHIy3TjrfVn1IyJ01RfWzSrAjLqOPhHVGBKkGtaaAlMgvw_Reh_GGm1WNyh7EUaH3MeBHNFk3Zz5dYHYx"
# url = "https://api.yelp.com/v3/businesses/search"
# query = "chicago"
# query_url = url + "api-key=" + api_key + "&q=" + query
# response = requests.get(query_url)
# print(response)
# # response_json = response.json()
# # print(json.dumps(response_json, indent=4, sort_keys=True))

# %%
url = "https://api.yelp.com/v3/businesses/search?location=chicago"

payload={}
headers = {
  'Authorization': 'Bearer TZRAh8OX5nwgY2J2Y2OWeKLqGI__SjwuVzr8V0wj4kHGSEAMHIy3TjrfVn1IyJ01RfWzSrAjLqOPhHVGBKkGtaaAlMgvw_Reh_GGm1WNyh7EUaH3MeBHNFk3Zz5dYHYx'
}

response = requests.request("GET", url, headers=headers, data=payload)

#print(response.text)
print(response.json())
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {'businesses': [{'id': 'qjnpkS8yZO8xcyEIy5OU9A', 'alias': 'girl-and-the-goat-chicago', 'name': 'Girl & The Goat', 'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yfuzM9PAqTYIYTusIg8U2A/o.jpg', 'is_closed': False, 'url': 'https://www.yelp.com/biz/girl-and-the-goat-chicago?adjust_creative=USJ2h80Yg9ZMtsY4il9h1w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=USJ2h80Yg9ZMtsY4il9h1w', 'review_count': 8714, 'categories': [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'bakeries', 'title': 'Bakeries'}, {'alias': 'coffee', 'title': 'Coffee & Tea'}], 'rating': 4.5, 'coordinates': {'latitude': 41.88415330470642, 'longitude': -87.64797390222085}, 'transactions': ['delivery'], 'price': '$$$', 'location': {'address1': '809 W Randolph St', 'address2': '', 'address3': '', 'city': 'Chicago', 'zip_code': '60607', 'country': 'US', 'state': 'IL', 'display_address': ['809 W Randolph St', 'Chicago, IL 60607']}, 'phone': '+13124926262', 'display_phone': '(312) 
# ...

# %%
restaurants = requests.get(url + "businesses").json()
print(restaurants)
# Out:
# {'error': {'code': 'VALIDATION_ERROR', 'description': 'Authorization is a required parameter.', 'field': 'Authorization', 'instance': None}}
