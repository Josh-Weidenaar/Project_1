# %%
import pandas as pd
import json as json
from sodapy import Socrata

client = Socrata("data.cityofchicago.org", 
                 "o5qU1IxOMy5FwwEf8MWwOz5TY",
                 username="michelle.goldberg@gmail.com",
                 password="3rpNdTQ!fuHGAx4")

results = client.get("yhhz-zm2v", limit=4000)

                 
results_df = pd.DataFrame.from_records(results)
results_df
# Out:
#      zip_code week_number               week_start                 week_end  \
# 0       60603          10  2020-03-01T00:00:00.000  2020-03-07T00:00:00.000
# 1       60603          11  2020-03-08T00:00:00.000  2020-03-14T00:00:00.000
# 2       60603          12  2020-03-15T00:00:00.000  2020-03-21T00:00:00.000
# 3       60603          13  2020-03-22T00:00:00.000  2020-03-28T00:00:00.000
# 4       60603          14  2020-03-29T00:00:00.000  2020-04-04T00:00:00.000
# ...       ...         ...                      ...                      ...
# 3295    60640           3  2021-01-17T00:00:00.000  2021-01-23T00:00:00.000
# 3296    60666          45  2020-11-01T00:00:00.000  2020-11-07T00:00:00.000
# 3297    60620          22  2020-05-24T00:00:00.000  2020-05-30T00:00:00.000
# 3298    60621          16  2020-04-12T00:00:00.000  2020-04-18T00:00:00.000
# 3299    60630          35  2020-08-23T00:00:00.000  2020-08-29T00:00:00.000
#
# ...

# %%
#drop "unknown" from zip code
#create heatmap

# %%
## data type and data structure
print(pd)
print(type(pd))
# Out:
# <module 'pandas' from '/Users/michellegoldberg/opt/anaconda3/lib/python3.8/site-packages/pandas/__init__.py'>
# <class 'module'>
