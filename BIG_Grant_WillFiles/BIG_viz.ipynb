# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Store filepaths in variables
big_key_stats = "big_key_stats.xlsx"
big_by_rev = "big_by_rev.xlsx"
big_by_ind = "big_industry.xlsx"
big_by_race = "big_race.xlsx"

# %%
# Read data file with pandas library
big_key_stats_df = pd.read_excel(big_key_stats)
big_by_rev_df = pd.read_excel(big_by_rev)
big_by_ind_df = pd.read_excel(big_by_ind)
big_by_race_df = pd.read_excel(big_by_race)

# %%
# Key stats
big_key_stats_df.head()
# Out:
#                          BIG Recipients  Number of Grants  \
# 0                        Minority-Owned              3597
# 1                           Woman-Owned              3347
# 2              Under $1M Annual Revenue              7381
# 3  In Disproportionately Impacted Areas              4211
# 4                In Downstate Counties*              3157
#
#    Percentage of Grants  Grant Amount (Millions)  Percentage of Funds
# 0                  0.40                       88                 0.32
# 1                  0.37                       85                 0.31
# 2                  0.82                      221                 0.80
# 3                  0.47                      116                 0.42
# 4                  0.35                      105                 0.38

# %%
# Key stats histogram

# %%
# BIG recipients by revenue
big_by_rev_df.head()
# Out:
#   2019 Revenues (millions of dollars)  Number of Grants  Percentage of Grants  \
# 0                                <0.5              5941                  0.66
# 1                               0.5-1              1440                  0.16
# 2                                 1-2              1021                  0.11
# 3                                 2-5               508                  0.06
# 4                                  >5                61                  0.01
#
#    Grant Amount (Millions)  Percentage of Funds
# 0                      176                 0.64
# 1                       45                 0.16
# 2                       34                 0.12
# 3                       18                 0.06
# 4                        3                 0.01

# %%
# BIG recipients by industry
big_by_ind_df
# Out:
#                                     Type of Industry  Number of Grants  \
# 0                               Restaurants and Bars              3747
# 1                           Gyms and Fitness Centers               636
# 2  Event spaces, concert venues, and performing a...               518
# 3                                  Indoor Recreation               269
# 4               Support services for arts and events               535
# 5                                 Tourism and Travel               515
# 6    Other priority and heavily impacted industries*              2105
#
#    Percentage of Grants  Grant Amount (Millions)  Percentage of Funds
# 0                  0.42                      133                 0.48
# 1                  0.07                       16                 0.06
# 2                  0.06                       25                 0.09
# 3                  0.03                       17                 0.06
# ...

# %%
# Bar chart for BIG recipients by industry
ind = ["Dining", "Fitness", "Events", "Rec", "Support", "Tourism", "Other"]
amt_ind = big_by_ind_df["Grant Amount (Millions)"]
x_axis_ind = np.arange(len(amt_ind))

# Create the ticks for our bar chart's x axis
tick_locations = [value for value in x_axis_ind]
plt.xticks(tick_locations, ind)

# Set the limits of the y axis
plt.ylim(0, max(amt_ind)+10)

# Give the chart a title and y label
plt.title("BIG Recipients by Industry")
plt.ylabel("Grants Received (Millions)")

plt.bar(x_axis_ind, amt_ind, color="b", align="center")

# Save an image of the chart and print it to the screen
plt.savefig("../Project_1/BarInd.png")
plt.show()

# %%
# Pie chart of BIG recipients by industry

# Labels for the sections of our pie chart
ind = ["Dining", "Fitness", "Events", "Rec", "Event Support", "Tourism", "Other"]

# The values of each section of the pie chart
amt_ind = big_by_ind_df["Grant Amount (Millions)"]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue", "blue", "purple", "green"]

# Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")

# Creates the pie chart based upon the values above 
# Automatically finds the percentages of each part of the pie chart
plt.pie(amt_ind, labels=ind, colors=colors, autopct="%1.1f%%", startangle=140)

# Save an image of the chart and print it to the screen
plt.savefig("../Project_1/PieInd.png")
plt.show()

# %%
# BIG recipients by race
big_by_race_df
# Out:
#                                    Race or Ethnicity  Number of Grants  \
# 0                                 White or Caucasian              4478
# 1                          Black or African American              1084
# 2                                 Hispanic or Latinx               765
# 3                 Asian American or Pacific Islander              1565
# 4  American Indian, Indigenous, Native American, ...                34
# 5                                        Multiracial               149
# 6                              Prefer not to respond               899
#
#    Percentage of Grants  Grant Amount (Millions)  Percentage of Funds  \
# 0                 0.500                      152                0.550
# 1                 0.120                       17                0.060
# 2                 0.090                       18                0.070
# 3                 0.170                       48                0.170
# ...

# %%
# Bar chart for BIG recipients by race
race = ["White", "Black", "Hispanic", "Asian", "Native Am", "Multi", "No Info"]
amt_race = big_by_race_df["Grant Amount (Millions)"]
x_axis_race = np.arange(len(amt_race))

# Create the ticks for our bar chart's x axis
tick_locations = [value for value in x_axis_race]
plt.xticks(tick_locations, race)

# Set the limits of the y axis
plt.ylim(0, max(amt_race)+10)

# Give the chart a title and y label
plt.title("BIG Recipients by Race")
plt.ylabel("Grants Received (Millions)")

plt.bar(x_axis_race, amt_race, color="r", align="center")

# Save an image of the chart and print it to the screen
plt.savefig("../Project_1/BarRace.png")
plt.show()

# %%
# Pie chart of BIG recipients by race

# Labels for the sections of our pie chart
race = ["White", "Black", "Hispanic", "Asian", "Native Am", "Multi", "No Info"]

# The values of each section of the pie chart
amt_race = big_by_race_df["Grant Amount (Millions)"]

# The colors of each section of the pie chart
colors = ["red", "orange", "lightcoral", "lightskyblue", "blue", "purple", "green"]

# Tells matplotlib that we want a pie chart with equal axes
plt.axis("equal")

# Creates the pie chart based upon the values above 
# Automatically finds the percentages of each part of the pie chart autopct="%1.1f%%"
plt.pie(amt_race, labels=race, colors=colors, autopct="%1.1f%%", startangle=140)

# Save an image of the chart and print it to the screen
plt.savefig("../Project_1/PieRace.png")
plt.show()
